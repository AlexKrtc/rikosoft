# %%
a=3+2
a
# Out:
# 5

# %% [markdown]
# "МЧП РИКО автоматизация торговли"
# Торговое оборудование : сканеры штрихкода, принтеры чеков, весы

# %%
from PIL import Image
import requests
#image_url = "https://upload.wikimedia.org/wikipedia/en/c/cd/Anaconda_Logo.png"
image_url="https://lh5.googleusercontent.com/p/AF1QipNmPKPIJLrR3CKlNyDrka3zN4JNuqVZ038DIE8t=w696-h240-k-no"
im = Image.open(requests.get(image_url,stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=696x240 at 0x6678CC8>

# %%
import random
rnd = random.random()
rnd
# Out:
# 0.12726765773554394
